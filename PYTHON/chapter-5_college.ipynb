# %%
d={"name":"jay","age":20,"phone":1234567890}
d["name"]="rudani"
d["age"]=19
d["Age"]=20
del d["Age"]
print(d)

# %%
d=eval(input("enter dictionary"))
print(d)

# %%
d={}
a=input("enter key")
b=input("enter value")
d[a]=b
print(d)

# %%
a={}
for i in range(3):
    b=eval(input("enter the players name: "))
    c=eval(input("enter the runs scored: "))
    a[b]=c
print(a)

# %%
d={"a":[1,2,3,4],"b":[5,6,7,8],"c":[9,0,12,11]}
d.get("a")
d["b"]
print(d)

# %%
d={"a":10,"b":20,"c":30,"d":40}
for i in d.keys():
    print(d[i])

# %%
name=["a","b","c","d"]
marks=[10,20,30,40]
z=dict(zip(name,marks))
print(z)

# %%
a={}
d=input("enter the string: ")
for i in d:
       a[i]=d.count(i)
print(a)

# %%
a={}
d=input("enter the string: ")
z=d.split(" ")
for i in z:
       a[i]=z.count(i)
print(a)

# %%
d="hi hello how are you i am fine are you fin"
z=d.split(" ")
x={}
for i in z:
    l=[]
    for j in z:
        if (i[0]==j[0]):
            l.append(j)
    x[i[0]]=l
print(x)

# %%
d={"a":10,"b":20,"c":40,"d":30}
z=sorted(d.items(),key=lambda i:i[1],reverse=True)
print(z)

# %%
def demo(n):
    d={0:"zero",1:"one",2:"two",3:"three",4:"four",5:"five",6:"six",7:"seven",8:"eight",9:"nine",10:"ten",11:"eleven",12:"twelve",
   13:"thirteen",14:"fourteen",15:"fifteen",16:"sixteen",17:"seventeen",18:"eighteen",19:"nineteen",20:"twenty",
   30:"thirty",40:"forty",50:"fifty",60:"sixty",70:"seventy",80:"eighty",90:"ninety",100:"hundred",1000:"thousand"}
    if n<=20:
        return d[n]
    if n<100:
        if n%10==0:
            return d[n]
        else:
            return d[(n//10)*10]+" "+d[n%10]
    if n<1000:
        if n%100==0:
            return d[n//100]
        else:
            return d[n//100]+" hundred "+demo(n%100)
z=demo(n=int(input("enter the number between 1-1000: ")))
print(z)

# %%
A={5,6,3,9,11,10}
B={1,7,3,0,11,13,6}
B.add(8)
C=frozenset(B)
B.add(15)
print(A.issubset(B))
print(B.issubset(A))
print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
print(B.difference(A))
print(B.symmetric_difference(A))
print(A|B)
print(A&B)
print(B^A)

# %%
from functools import*
l=[1,2,3,4]
z=set(map(lambda i:i+20,l))
print(z)
z=tuple(filter(lambda i:i%2==0,l))
print(z)
z=reduce(lambda x,y:x*y,l)
print(z)

# %%
s="hello good morning"
ans=str.maketrans("ohg","@#9","n")
sol=s.translate(ans)
print(sol)

# %%
s="my name is bull cow"
ans=str.maketrans("abc","def")
sol=s.translate(ans)
print(sol)

# %%
s="he@#. INDIA is =,921"
ans=str.maketrans("I","i","@#.,=")
sol=s.translate(ans)
print(sol)
# Out:
# he iNDiA is 921

# %%
n=int(input("Enter the Number: "))
num=[1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]
roman=["M","CM","D","CD","C","XC","L","XL","X","IX","V","IV","I"]
ans=" "
i=0
while n>0:
    for J in range(n//num[i]):
        ans=ans+roman[i]
        n=n-num[i]
    i=i+1
print(ans)
# Out:
# Enter the Number: 58
#  LVIII

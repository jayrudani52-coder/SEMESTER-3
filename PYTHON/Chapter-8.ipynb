# %%
import os2

# %%
a=10
b=0
c=a/b
print(c)

# %%
print("a")
 print("v")

# %%
a=110
print(z)

# %%
l=[1,2,3,4]
print(l[7])

# %%
print("hi")
if a>10
    print("bye")

# %%
a="xyz"
x=int(a)

# %%
d={1,2,3,4}
print(d[10])

# %%
a="cdbc"
x=a.append("10")

# %%
d={1:1,2:2,3:3}
print(d[5])

# %%
try:
    f=open("1.txt")
except Exception as e:
    print(e)
else:
    x=f.read()
    print(x)

# %%
try:
    a=10
    b=0
    c=a/b
    print(c)
except:
    print("java de")
finally:
    print("hello")

# %%
try:
    a=10
    b=0
    print(d)
    print(a/b)
except NameError as z:
    print(z)
except ZeroDivisionError as e:
    print(e)
finally:
    print("hello")

# %%
class demo(Exception):
    pass
try:
    n=int(input("enter your number: "))
    n=str(n)
    if len(n)==10 and n.startswith("9"):
        raise demo("Success")
    else:
        print("Please Enter number of 10 Digits and should start with 9 only")
except demo as e:
    print(e)

# %%
import datetime
from datetime import time,date,datetime
x=datetime.now()
print(x)
print(x.year)
print(x.month)
print(x.day)
print(x.today())

# %%
import datetime
from datetime import time,date,datetime
y=datetime(2005,7,21,12,0,0)
print(y)
x=datetime.now()
print(x)

# %%
import datetime
from datetime import time,date,datetime
a=int(input("enter year: "))
b=int(input("enter month: "))
c=int(input("enter days: "))
y=datetime(a,b,c)
print(y)
x=datetime.now()
print(x)

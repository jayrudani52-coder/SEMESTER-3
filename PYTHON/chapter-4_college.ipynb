# %%
y=input("Enter the password")
c=len(y)
a=0
b=0
e=0
d=0
f=0
if c>8:
    for i in y:
        if i.isupper():
            a=a+1
        elif i.islower():
            b=b+1
        elif i.isnumeric():
            e=e+1
        elif i.isspace():
            f=f+1
        else:
            d=d+1
    if (a>0 and b>0 and e>0 and d>0 and f==0):
        print("correct")
else:
    print("incorrect")

# %%
count=0
while(count==3):
    y=input("Enter the password")
    c=len(y)
    a=0
    b=0
    e=0
    d=0
    f=0
    if c>8:
        for i in y:
            if i.isupper():
                a=a+1
            elif i.islower():
                b=b+1
            elif i.isnumeric():
                e=e+1
            elif i.isspace():
                f=f+1
            else:
                d=d+1
        if (a>0 and b>0 and e>0 and d>0 and f==0):
            print("correct")
    else:
        print("incorrect")

# %%
x=input("enter string")
y=x.split(" ")
for i in y:
    if i[0]=="o":
        print(i)
    else:
        print("nothing")

# %%
x=input("enter string")
y=x.split(" ")
for i in y:
    if i[0]==i[-1]:
        print(i)
    else:
        print("nothing")

# %%
x=input("enter string")
y=x.split(" ")
for i in y:
    print(i[::-1])

# %%
x=input("enter string")
y=x.split(" ")
for i in y:
    print(i[0].upper()+i[1:-1]+i[-1].upper())

# %%
x=int(input("enter the number")
n=int(input("enter the number to shift"))
x=str(x)
print(x[n: :]+x[0:n:])

# %%
x=input("enter the string")
y=x.split(" ")
a=0
sum=0
for i in y:
    if i.isdigit():
        i=int(i)
        sum=sum+i
        a=a+1
print("sum",sum)
print("average",sum/a)

# %%
x=input("enter the string")
y=""
n=int(input("enter the number"))
for i in x:
    y=y+chr(ord(i)+n)
print(y)

# %%
Z="XYZ abc"
k=3
final=""
z=Z.upper()
ans="ABCDEFGHIJKLMNOPQRSTUVWXYZ"
for i in z:
    if i in ans:
        op=(ans.find(i)+k)%26
        final=final+ans[op]
    else:
        final=final+i
print(final)

# %%
x=input("enter the string")
y=x.split(" ")
z=""
for i in y:
        z=z+i[0]
        print(z.upper())

# %%
x=input("enter the string")
y=x.split(" ")
a=""
for i in y:
    if i.isupper(): 
        a=a+i.lower()
    elif i.islower():
        a=a+i.upper()
    else:
        a=a+i
print(a)

# %%
x=(10,20,30,"dhoni",10.5)
print(x)
print(type(x))
print(x[:2:])
print(x[::-1])
print(x[0:-1])
y=eval(input("enter string"))
print(y)

# %%
x=eval(input("enter number"))
evensum=0
oddsum=0
for i in x:
    if i%2==0:
        evensum=evensum+i
    else:
        oddsum=oddsum+i
print(evensum,oddsum)

# %%
x=(10,20,30,40,50)
y=int(input("enter index to delete"))
print(x[0:y-1]+x[y::])

# %%
x=(10,20,30,40,50)
z=90
y=int(input("enter index to replace"))
print(x[0:y-1]+(z,)+x[y::])

# %%
x=(10,20,30,40,50)
z=90
y=int(input("enter index to insert"))
print(x[0:y-1]+(z,)+x[y-1::])

# %%
x=(1,2,1,2,3,4,2,1,1,9,2,1,3,2,2)
y=sorted(x)
for i in y:
    print(i,"+",end=" ")

# %%
l=[10,20,30,40]
l1=["dvp",40,30,20,10]

l.append("hello")
print(l)

l.pop()
print(l)

l.reverse()
print(l)

del l[1]
print(l)

l.insert(1,90)
print(l)

l.sort()
print(l)

l.extend(l1)
print(l)

l.clear()
print(l)

# %%
n=[]
for i in range (1,5):
    name=input("enter th name")
    n.append(name)
print(n)

# %%
x=[[1,2,3],[4,5,6],[7,8,9]]
y=[]
for i in x:
    y=y+i
print(y)

# %%
x=[1,2,3,4,5,6,7,8,9]
even=[]
odd=[]
for i in x:
    if i%2==0:
        even.append(i)
    else:
        odd.append(i)
print(max(even),max(odd))

# %%
l=[1,2,3,4]
z=[]
for i in l:
    z.append(i**2)
print(z)

# %%
l=[1,2,3,4]
z=[i**2 for i in l if i%2==0]
print(z)

# %%
l=[1,2,3,4]
z=[i**2 if i%2==0 else i**3 for i in l]
print(z)

# %%
z="jay"
for i,j in enumerate(z,start=10):
    print(i,j)

# %%
import copy
l=[[1,2,3],[4,5,6]]
z=copy.deepcopy(l)
l[0][2]=30
print(l)
print(z)

# %%
y=[]
for i in range(1,11):
    x=eval(input("enter the numbers"))
    y.append(x)
print(y)

# %%
evenmax=[]
oddmax=[]
evenmin=[]
oddmin=[]
for i in range(1,10):
    x=eval(input("enter the number"))
    if i%2==0:
        evenmax.append(i)
    else:
        oddmax.append(i)
print(max(evenmax),max(oddmax))

# %%
x=["pyt","pytho","python","pyth"]
x.sort(reverse=True)
z=" "
for i in range(len(x[-1])):
    if x[0][i]==x[-1][i]:
        z=z+x[-1][i]
        continue
    else:
        print("Not alid")
        break
print(z)

# %%
l=[5,5,2,5,8 ]
for i in range(len(l)):
    x=l.copy()
    z=x.pop(i)
    sum1=sum(x[::2])
    sum2=sum(x[1::2])
    if sum1==sum2:
        print("remianing numbers are :",z)

# %%
l=[1,2,12,15,79,68,86,59,34]
for i in l:
    if i>10 and i%2!=0:
            print(i)
